# %% [markdown]
# ### Q1. How many rows and columns are present in the Iris dataset?

# %%
import pandas as pd
df=pd.read_csv("iris.csv")

# %%
print(df.shape)
df.head()
# Out:
# (150, 5)
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ### Q2. How many unique species exist in the dataset?

# %%
df['variety'].nunique()
# Out:
# 3

# %% [markdown]
# ### Q3. What is the average sepal length?

# %%
df['sepal.length'].mean()
# Out:
# np.float64(5.843333333333334)

# %% [markdown]
# ### Q4. How many flowers have a petal width > 1.5 cm?

# %%
df[df['petal.width']>1.5].shape[0]
# Out:
# 52

# %% [markdown]
# ### Q5. Are there any missing values in the dataset?

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %% [markdown]
# ### Q6. Which species has the largest average petal length?

# %%
df.groupby('variety')['petal.length'].mean()
# Out:
# variety
# Setosa        1.462
# Versicolor    4.260
# Virginica     5.552
# Name: petal.length, dtype: float64

# %% [markdown]
# ### Q7. Find the min, max, and mean of sepal width.

# %%
print("min: ",df['sepal.width'].min())
print("max: ",df['sepal.width'].max())
print("mean: ",df['sepal.width'].mean())
# Out:
# min:  2.0
# max:  4.4
# mean:  3.0573333333333337

# %% [markdown]
# ### Q8. How many samples have sepal_length > 6 AND petal_length > 5?

# %%
df[(df['sepal.length']>6)&(df['sepal.width']>5)].shape[0]
# Out:
# 0

# %% [markdown]
# ### Q9. Compute the correlation between sepal_length and petal_length.

# %%
df['sepal.length'].corr(df['petal.length'])
# Out:
# np.float64(0.8717537758865831)

# %% [markdown]
# ### Q10. For each species, find the median petal_width.

# %%
df.groupby('variety')['petal.width'].median()
# Out:
# variety
# Setosa        0.2
# Versicolor    1.3
# Virginica     2.0
# Name: petal.width, dtype: float64
