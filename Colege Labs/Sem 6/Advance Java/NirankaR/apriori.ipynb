# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules

# %%
transaction=[['eggs','milk','bread'],
            ['eggs','apple'],
            ['milk','bread'],
            ['apple','milk'],
            ['milk']
            ]
